# %%
# Load data
events_oct = spark.read.csv("/Volumes/workspace/ecommerce_idc/ecommerce_data_idc/2019-Oct.csv",header=True,inferSchema=True)

# %% [markdown]
# ### Pyspark Transformations

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

# %% [markdown]
# #### Top 5 products by revenue

# %%
# Top 5 products by revenue
revenue = events_oct.filter(F.col("event_type") == "purchase") \
    .groupBy("product_id") \
    .agg(F.sum("price").alias("revenue")) \
    .orderBy(F.desc("revenue")).limit(5)
display(revenue)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>revenue</th></tr></thead><tbody><tr><td>1005115</td><td>1.2406807350000003E7</td></tr><tr><td>1005105</td><td>1.0239248679999996E7</td></tr><tr><td>1004249</td><td>6730112.920000011</td></tr><tr><td>1005135</td><td>5567806.640000007</td></tr><tr><td>1004767</td><td>5430723.430000007</td></tr></tbody></table></div>

# %% [markdown]
# #### Ruuning Total per user

# %%
# Running total per user
window = Window.partitionBy("user_id").orderBy("event_time")
events_oct.withColumn("cumulative_events", F.count("*").over(window)).show()
# Out:
# +-------------------+----------+----------+-------------------+--------------------+--------+------+---------+--------------------+-----------------+
# |         event_time|event_type|product_id|        category_id|       category_code|   brand| price|  user_id|        user_session|cumulative_events|
# +-------------------+----------+----------+-------------------+--------------------+--------+------+---------+--------------------+-----------------+
# |2019-10-09 10:30:19|      view|  17301541|2053013553853497655|                NULL|    NULL|162.17|205053188|e1eadbc6-aef5-4cf...|                1|
# |2019-10-09 10:30:44|      view|  17301541|2053013553853497655|                NULL|    NULL|162.17|205053188|e1eadbc6-aef5-4cf...|                2|
# |2019-10-07 06:23:01|      view|  16200119|2053013556344914381|   kids.fmcg.diapers|   moony| 18.47|222907508|cb653adc-46a2-4d9...|                1|
# |2019-10-07 06:26:23|      view|  16200162|2053013556344914381|   kids.fmcg.diapers|   moony| 18.47|222907508|cb653adc-46a2-4d9...|                2|
# |2019-10-08 14:29:09|      view|   6200883|2053013552293216471|appliances.enviro...|elenberg| 46.31|244673419|e2f0524c-bfc4-4c6...|                1|
# |2019-10-12 10:15:48|      view|  17300355|2053013553853497655|                NULL|   creed|240.16|257849716|71e76013-465a-464...|                1|
# |2019-10-22 22:05:40|      view|   3900896|2053013552326770905|appliances.enviro...|   klima|  77.2|266203246|c83d6f3d-2973-411...|                1|
# |2019-10-24 01:14:36|      view|   3900896|2053013552326770905|appliances.enviro...|   klima|  77.2|266203246|56944410-059f-4f0...|                2|
# |2019-10-06 11:29:22|      view|  22700574|2053013556168753601|                NULL|    NULL| 88.81|278272605|e4cd7037-61d8-461...|                1|
# |2019-10-06 11:30:58|      view|  22700129|2053013556168753601|                NULL|   stels| 66.93|278272605|0a20874c-c88c-462...|                2|
# |2019-10-06 11:31:53|      view|  22700078|2053013556168753601|                NULL|   stels|180.18|278272605|0a20874c-c88c-462...|                3|
# |2019-10-06 11:34:45|      view|  22700078|2053013556168753601|                NULL|   stels|180.18|278272605|0a20874c-c88c-462...|                4|
# |2019-10-06 16:56:05|      view|  22700078|2053013556168753601|                NULL|   stels|180.18|278272605|ef4dccc3-e1ca-4bd...|                5|
# |2019-10-25 09:31:11|      view|   1004209|2053013555631882655|electronics.smart...| samsung| 88.79|279209491|fd193b03-0327-46e...|                1|
# |2019-10-23 01:01:59|      view|  26402687|2053013563651392361|                NULL|    NULL|375.97|284628126|56de7dcd-ad20-42e...|                1|
# |2019-10-27 19:35:43|      view|  28717970|2053013565782098913|       apparel.shoes|  rieker| 86.23|299004865|8c8ebbd4-0e10-44c...|                1|
# |2019-10-30 16:17:28|      view|   1307350|2053013558920217191|  computers.notebook|    acer|514.79|301573329|1cdccb65-48e7-4b9...|                1|
# |2019-10-30 16:18:11|      view|   1307350|2053013558920217191|  computers.notebook|    acer|514.79|301573329|1cdccb65-48e7-4b9...|                2|
# |2019-10-30 16:18:19|      view|   1307361|2053013558920217191|  computers.notebook|  lenovo| 420.6|301573329|1cdccb65-48e7-4b9...|                3|
# |2019-10-30 16:20:12|      view|   1307071|2053013558920217191|  computers.notebook|    acer|643.26|301573329|1cdccb65-48e7-4b9...|                4|
# +-------------------+----------+----------+-------------------+--------------------+--------+------+---------+--------------------+-----------------+
# only showing top 20 rows

# %%
events_oct.select("event_type").distinct().show()
# Out:
# +----------+
# |event_type|
# +----------+
# |  purchase|
# |      cart|
# |      view|
# +----------+

# %% [markdown]
# #### Conversion rate by category

# %%
# Conversion rate by category
events_oct.groupBy("category_code", "event_type").count().filter(F.col("category_code") == "kids.swing").show()
# Out:
# +-------------+----------+-----+
# |category_code|event_type|count|
# +-------------+----------+-----+
# |   kids.swing|  purchase|  330|
# |   kids.swing|      view|31596|
# |   kids.swing|      cart|  147|
# +-------------+----------+-----+

# %%
result_df = events_oct.groupBy("category_code", "event_type").count() \
    .groupBy("category_code")\
    .pivot("event_type").sum("count")\
    .withColumn("conversion_rate", F.col("purchase")/F.col("view")*100)

display(result_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category_code</th><th>cart</th><th>purchase</th><th>view</th><th>conversion_rate</th></tr></thead><tbody><tr><td>auto.accessories.parktronic</td><td>null</td><td>46</td><td>12305</td><td>0.3738317757009346</td></tr><tr><td>furniture.living_room.sofa</td><td>null</td><td>1084</td><td>215471</td><td>0.5030839416905292</td></tr><tr><td>stationery.cartrige</td><td>106</td><td>134</td><td>7380</td><td>1.8157181571815717</td></tr><tr><td>sport.bicycle</td><td>693</td><td>838</td><td>128759</td><td>0.6508282916145668</td></tr><tr><td>apparel.sock</td><td>7</td><td>21</td><td>2621</td><td>0.8012209080503624</td></tr><tr><td>appliances.environment.fan</td><td>16</td><td>27</td><td>2172</td><td>1.2430939226519337</td></tr><tr><td>kids.swing</td><td>147</td><td>330</td><td>31596</td><td>1.044436004557539</td></tr><tr><td>electronics.audio.microphone</td><td>196</td><td>430</td><td>28394</td><td>1.5144044516447137</td></tr><tr><td>auto.accessories.radar</td><td>716</td><td>494</td><
# %% [markdown]
# #### Joins

# %%
orders = spark.createDataFrame([
    (1, 101),
    (2, 102),
    (3, 101),
    (4, 104)
], ["order_id", "customer_id"])

customers = spark.createDataFrame([
    (101, "Alice"),
    (102, "Bob"),
    (103, "Carol")
], ["customer_id", "customer_name"])

# %%
inner_df = customers.join(orders, "customer_id","inner")
inner_df.show()
# Out:
# +-----------+-------------+--------+
# |customer_id|customer_name|order_id|
# +-----------+-------------+--------+
# |        101|        Alice|       3|
# |        101|        Alice|       1|
# |        102|          Bob|       2|
# +-----------+-------------+--------+

# %%
left_df = customers.join(orders, "customer_id","left")
left_df.show()
# Out:
# +-----------+-------------+--------+
# |customer_id|customer_name|order_id|
# +-----------+-------------+--------+
# |        101|        Alice|       3|
# |        101|        Alice|       1|
# |        102|          Bob|       2|
# |        103|        Carol|    NULL|
# +-----------+-------------+--------+

# %%
right_df = customers.join(orders, "customer_id","right")
right_df.show()
# Out:
# +-----------+-------------+--------+
# |customer_id|customer_name|order_id|
# +-----------+-------------+--------+
# |        101|        Alice|       1|
# |        102|          Bob|       2|
# |        101|        Alice|       3|
# |        104|         NULL|       4|
# +-----------+-------------+--------+

# %%
outer_df = customers.join(orders, "customer_id","outer")
outer_df.show()
# Out:
# +-----------+-------------+--------+
# |customer_id|customer_name|order_id|
# +-----------+-------------+--------+
# |        101|        Alice|       1|
# |        102|          Bob|       2|
# |        101|        Alice|       3|
# |        104|         NULL|       4|
# |        103|        Carol|    NULL|
# +-----------+-------------+--------+

# %% [markdown]
# #### UDF

# %%
orders = spark.createDataFrame([
    (1, 101, 12000),
    (2, 102, 45000),
    (3, 101, 8000),
    (4, 103, 67000),
    (5, 104, 3000)
], ["order_id", "customer_id", "order_amount"])

orders.show()
# Out:
# +--------+-----------+------------+
# |order_id|customer_id|order_amount|
# +--------+-----------+------------+
# |       1|        101|       12000|
# |       2|        102|       45000|
# |       3|        101|        8000|
# |       4|        103|       67000|
# |       5|        104|        3000|
# +--------+-----------+------------+

# %%
def order_value_category(amount):
    if amount < 10000:
        return "LOW"
    elif amount <= 50000:
        return "MEDIUM"
    else:
        return "HIGH"

# %%
from pyspark.sql.types import StringType
from pyspark.sql.functions import udf

order_value_udf = udf(order_value_category, StringType())

# %%
orders_with_category = orders.withColumn(
    "order_category",
    order_value_udf(orders["order_amount"])
)

orders_with_category.show()
# Out:
# +--------+-----------+------------+--------------+
# |order_id|customer_id|order_amount|order_category|
# +--------+-----------+------------+--------------+
# |       1|        101|       12000|        MEDIUM|
# |       2|        102|       45000|        MEDIUM|
# |       3|        101|        8000|           LOW|
# |       4|        103|       67000|          HIGH|
# |       5|        104|        3000|           LOW|
# +--------+-----------+------------+--------------+
